# %% [markdown]
# # Projet pour le cours POG
# ## Groupe 4 - Animatronics
# ### Guider un visiteur d'un endroit à un autre à HEC
# ---
# ### Initialisation
# Ceci est le point d'entrée de notre projet. Nous définissons ici des variables propres à l'environnement Jupyter.
# ```
# %reload_ext autoreload
# %autoreload 2
# %matplotlib
# ```
#
# Nous importons ensuite les différentes librairies et modules nécessaires.
#
# Nous avons fait le choix de déplacer certaines fonctions que nous réutilisons plusieurs fois, ainsi que l'Algorithme D*Lite dans leurs propres fichiers.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib

import matplotlib.pyplot as plt

# importe le simulateur depuis simulateur.py
from simulateur import *

# importe l'algorithme RRT*
from PythonRobotics.PathPlanning.RRTStar.rrt_star import RRTStar

# importe l'algorithme DStarLite
from dstarlite import DStar

# Nos propres fonctions
from helpers import *
# Out:
# Using matplotlib backend: TkAgg

# %% [markdown]
# ### Initialisation de l'environnement de simulation

# %%
room = DogRoom("maps/map01.csv") # Carte de base, simple
# room = DogRoom("maps/mapHEC.csv") # Carte du Hall d'HEC
dog = Dog(room, speed=1)

createImgRoom(room) # Création d'une élément dans la room afin de pouvoir effectuer des imshow

# %%
showmap(room, dog)

# %% [markdown]
# ### D*lite
#
# Nous avons repris l'Algorithme [D\*lite](https://www.aaai.org/Papers/AAAI/2002/AAAI02-072.pdf) (Koenig, S., & Likhachev, M. (2002). D\* lite. *Aaai/iaai, 15.*). Une vidéo explicative de l'algorithme peut être trouvé [ici](https://www.youtube.com/watch?v=_4u9W1xOuts).
#
# Ce dernier a été porté en Python par [Huiming Zhou](https://github.com/zhm-real/PathPlanning).
# Nous avons apporté quelques modifications afin de l'adapter à notre contexte

# %%
# Définit les points de départ et d'arrivée. 
# Obligation d'utiliser des coordonnées entières pour l'algorithme D*Lite
s_start = (round(dog.x,0), round(dog.y,0))
s_goal = (18,35)

#Initialise l'algorithme
dstar = DStar(room, s_start, s_goal, "euclidean")

#Exécute l'algorithme
dstar.run()

#Récupère le chemin généré
pathDStar = dstar.extract_path()
# Out:
# Algorithme exécuté

# %%
showmap(room, dog, path=pathDStar, goal=s_goal)

# %%
MoveUsingPath(room, dog=dog, goal=s_goal, path=pathDStar)
# Out:
# 206812237, Current Y: 133.91564950505511
# Goal X: 18, Goal Y: 133
# Angle absolu 91.48967870241215
# Angle relatif 3.758212678388958
# Distance à parcourir 0.9159590769766629
# --------------
# Current X: 18.011224382098497, Current Y: 132.92839259923403
# Goal X: 18, Goal Y: 132
# Angle absolu 90.69267935836324
# Angle relatif -0.8201270291473861
# Distance à parcourir 0.9284604488431435
# --------------
# Current X: 17.967200115456176, Current Y: 131.93511041516146
# Goal X: 18, Goal Y: 131
# Angle absolu 87.99111978850642
# Angle relatif -2.7052432276825016
# Distance à parcourir 0.935685481863178
# --------------
# Current X: 18.031319752787585, Current Y: 130.9153247475678
# Goal X: 18, Goal Y: 130
# Angle absolu 91.95973047955835
# Angle relatif 3.96142955978074
# Distance à parcourir 0.9158604262794348
# --------------
# Current X: 18.00933365261269, Current Y: 129.96883385920574
# Goal X: 18, Goal Y: 129
# Angle absolu 90.55196497659065
# Angle relatif -1.432882442941164
# Distance à parcourir 0.968878817920276
# --------------
# Current X: 18.035408251874653, Current Y: 128.95690205988433
# Goal X: 18, Goal Y: 128
# Angle absolu 92.11914918326579
# Angle relatif 1.5692957438081834
# Distance à parcourir 0.9575569416550063
# --------------
# Current X: 18.01240616659485, Current Y: 127.9083675905413
# Goal X: 18, Goal Y: 127
# Angle absolu 90.78247705153319
# Angle relatif -1.3292329522754471
# Distance à parcourir 0.9084523061313631
# --------------
# Current X: 18.032990709458385, Current Y: 126.96641103456086
# Goal X: 18, Goal Y: 126
# Angle absolu 91.95516668987744
# Angle relatif 1.1795453827175635
# Distance à parcourir 0.9669739782597906
# --------------
# Current X: 17.962145143067293, Current Y: 125.89243320587249
# Goal X: 18, Goal Y: 125
# Angle absolu 87.57110771779907
# Angle relatif -4.38954615320587
# Distance à parcourir 0.8932357007740179
# --------------
# Current X: 17.97078442866827, Current Y: 125.00405077323937
# Goal X: 18, Goal Y: 124
# Angle absolu 88.3332946973507
# Angle relatif 0.790581396311012
# Distance à parcourir 1.0044757363176162
# --------------
# Current X: 18.035020693082185, Current Y: 123.91882545607052
# Goal X: 18, Goal Y: 123
# Angle absolu 92.18275091608415
# Angle relatif 3.85340643869408
# Distance à parcourir 0.9194926142537302
# --------------
# Current X: 17.99973936486651, Current Y: 122.98143610560841
# Goal X: 18, Goal Y: 122
# Angle absolu 89.98478424351275
# Angle relatif -2.223658632201804
# Distance à parcourir 0.9814361402162007
# --------------
# Current X: 18.00938319079088, Current Y: 121.89853661010456
# Goal X: 18, Goal Y: 121
# Angle absolu 90.59830360093959
# Angle relatif 0.5999984231260953
# Distance à parcourir 0.8985856019142566
# --------------
# Current X: 18.023034786963002, Current Y: 120.96849157137491
# Goal X: 18, Goal Y: 120
# Angle absolu 91.36247679822668
# Angle relatif 0.761149282150754
# Distance à parcourir 0.96876546451382
# --------------
# Current X: 17.96268437644133, Current Y: 119.9444965522496
# Goal X: 18, Goal Y: 119
# Angle absolu 87.73750751624875
# Angle relatif -3.6197949444866566
# Distance à parcourir 0.9452334066107482
# --------------
# Current X: 17.977834843035517, Current Y: 118.97626124848271
# Goal X: 18, Goal Y: 118
# Angle absolu 88.6993729371092
# Angle relatif 0.9486502164444914
# Distance à parcourir 0.9765128363069727
# --------------
# Current X: 18.015034874535, Current Y: 117.96201496211332
# Goal X: 18, Goal Y: 117
# Angle absolu 90.89537560764072
# Angle relatif 2.1897104075084
# Distance à parcourir 0.9621324413936817
# --------------
# Current X: 17.984315546524936, Current Y: 116.97558703026736
# Goal X: 18, Goal Y: 116
# Angle absolu 89.07893857966837
# Angle relatif -1.8381911547780874
# Distance à parcourir 0.9757131011248664
# --------------
# Current X: 17.992074145547434, Current Y: 115.97515800896639
# Goal X: 18, Goal Y: 115
# Angle absolu 89.53432366280573
# Angle relatif 0.45184012375592886
# Distance à parcourir 0.9751902181728933
# --------------
# Current X: 17.98768751708026, Current Y: 114.93787343144146
# Goal X: 18, Goal Y: 114
# Angle absolu 89.24785929564902
# Angle relatif -0.28649555221529965
# Distance à parcourir 0.9379542476258785
# --------------
# Current X: 17.97485953011661, Current Y: 113.96297439098099
# Goal X: 18, Goal Y: 113
# Angle absolu 88.50451298893184
# Angle relatif -0.7427942080348799
# Distance à parcourir 0.9633025074768383
# --------------
# Current X: 18.02788214896235, Current Y: 112.95201655947457
# Goal X: 18, Goal Y: 112
# Angle absolu 91.67756843632567
# Angle relatif 3.1779714698254224
# Distance à parcourir 0.9524247706483489
# --------------
# Current X: 17.96774237684671, Current Y: 111.92284146245143
# Goal X: 18, Goal Y: 111
# Angle absolu 87.99805974094248
# Angle relatif -3.6619096644973297
# Distance à parcourir 0.9234050677091792
# --------------
# Current X: 18.023367440502227, Current Y: 110.93375757260958
# Goal X: 18, Goal Y: 110
# Angle absolu 91.4335373258189
# Angle relatif 3.4380985114213303
# Distance à parcourir 0.9340499139132549
# --------------
# Current X: 18.015042756827214, Current Y: 109.94002019424504
# Goal X: 18, Goal Y: 109
# Angle absolu 90.91680255761447
# Angle relatif -0.504250110075489
# Distance à parcourir 0.9401405480679147
# --------------
# Current X: 18.035440274467636, Current Y: 108.91316450184718
# Goal X: 18, Goal Y: 108
# Angle absolu 92.22255634209321
# Angle relatif 1.305413313471206
# Distance à parcourir 0.9138519685858014
# --------------
# Current X: 18.031459523812472, Current Y: 107.95014302132351
# Goal X: 18, Goal Y: 107
# Angle absolu 91.89638785350739
# Angle relatif -0.33632415981223573
# Distance à parcourir 0.950663695850578
# --------------
# Current X: 18.025424179392683, Current Y: 106.99165665747064
# Goal X: 18, Goal Y: 106
# Angle absolu 91.46863243792995
# Angle relatif -0.42693063488503924
# Distance à parcourir 0.9919825175897194
# --------------
# Current X: 18.02548588995767, Current Y: 106.017728427004
# Goal X: 18, Goal Y: 105
# Angle absolu 91.43449742672861
# Angle relatif -0.037859208371500586
# Distance à parcourir 1.0180474850020378
# --------------
# Current X: 17.966774745298604, Current Y: 104.87694431032901
# Goal X: 18, Goal Y: 104
# Angle absolu 87.83024218692304
# Angle relatif -3.603952478425896
# Distance à parcourir 0.8775734960494154
# --------------
# Current X: 18.033887393521724, Current Y: 103.9237694277838
# Goal X: 18, Goal Y: 103
# Angle absolu 92.10088614185022
# Angle relatif 4.306423506471106
# Distance à parcourir 0.9243907783766009
# --------------
# Current X: 18.03003951207121, Current Y: 102.94616490708687
# Goal X: 18, Goal Y: 102
# Angle absolu 91.8184560704564
# Angle relatif -0.286142775529143
# Distance à parcourir 0.9466416448097859
# --------------
# Current X: 17.986231894031906, Current Y: 101.9454307651937
# Goal X: 18, Goal Y: 101
# Angle absolu 89.16567279738035
# Angle relatif -2.6538605470106233
# Distance à parcourir 0.9455310108699263
# --------------
# Current X: 18.021819547162245, Current Y: 100.96615842271136
# Goal X: 18, Goal Y: 100
# Angle absolu 91.29373760899347
# Angle relatif 2.130611549933022
# Distance à parcourir 0.9664047756579368
# --------------
# Current X: 17.995165087107114, Current Y: 99.89922857611104
# Goal X: 18, Goal Y: 99
# Angle absolu 89.69193880065825
# Angle relatif -1.6042031645784647
# Distance à parcourir 0.8992415740374632
# --------------
# Current X: 18.016578037113806, Current Y: 98.98520659906615
# Goal X: 18, Goal Y: 98
# Angle absolu 90.9640231056415
# Angle relatif 1.280305074544728
# Distance à parcourir 0.9853460682207181
# --------------
# Current X: 18.026363308239286, Current Y: 97.93939030895741
# Goal X: 18, Goal Y: 97
# Angle absolu 91.60754258263982
# Angle relatif 0.6375403883295547
# Distance à parcourir 0.9397601697158829
# --------------
# Current X: 18.01356924710923, Current Y: 96.90326931161447
# Goal X: 18, Goal Y: 96
# Angle absolu 90.86065374395817
# Angle relatif -0.7419264409851962
# Distance à parcourir 0.9033712270000535
# --------------
# Current X: 18.034268318518578, Current Y: 95.95014105918152
# Goal X: 18, Goal Y: 95
# Angle absolu 92.06556629240968
# Angle relatif 1.1992686791872131
# Distance à parcourir 0.9507588285136609
# --------------
# Current X: 18.002033924854434, Current Y: 94.92956287777783
# Goal X: 18, Goal Y: 94
# Angle absolu 90.1253655097679
# Angle relatif -1.950158944722105
# Distance à parcourir 0.9295651029341127
# --------------
# Current X: 18.01783376941635, Current Y: 93.94371540516805
# Goal X: 18, Goal Y: 93
# Angle absolu 91.08261252129552
# Angle relatif 0.975539241201048
# Distance à parcourir 0.9438838960820823
# --------------
# Current X: 17.96098390399804, Current Y: 92.94019208975274
# Goal X: 18, Goal Y: 92
# Angle absolu 87.62370289325949
# Angle relatif -3.46514204333144
# Distance à parcourir 0.9410012865989408
# --------------
# Current X: 18.024688636632114, Current Y: 91.96235184220605
# Goal X: 18, Goal Y: 91
# Angle absolu 91.46957111793918
# Angle relatif 3.8512596700631576
# Distance à parcourir 0.9626684771904215
# --------------
# Current X: 17.99760193565611, Current Y: 90.93788715913905
# Goal X: 18, Goal Y: 90
# Angle absolu 89.85350192168994
# Angle relatif -1.6387371281302876
# Distance à parcourir 0.9378902249146853
# --------------
# Current X: 17.967125495516367, Current Y: 89.98718642328542
# Goal X: 18, Goal Y: 89
# Angle absolu 88.09268593630601
# Angle relatif -1.7667694710486188
# Distance à parcourir 0.9877336520358659
# --------------
# Current X: 18.022233452373023, Current Y: 88.96601341291625
# Goal X: 18, Goal Y: 88
# Angle absolu 91.31846836189467
# Angle relatif 3.2140296833593567
# Distance à parcourir 0.9662692380172998
# --------------
# Current X: 17.964401845209427, Current Y: 87.98663688864498
# Goal X: 18, Goal Y: 87
# Angle absolu 87.93364743468958
# Angle relatif -3.3726778337627508
# Distance à parcourir 0.9872788758296925
# --------------
# Current X: 17.990252474301027, Current Y: 86.9190497918575
# Goal X: 18, Goal Y: 86
# Angle absolu 89.39233853467843
# Angle relatif 1.4757021632780578
# Distance à parcourir 0.9191014819760506
# --------------
# Current X: 17.9860508130326, Current Y: 85.96609736388139
# Goal X: 18, Goal Y: 85
# Angle absolu 89.17278109055586
# Angle relatif -0.2202819605524411
# Distance à parcourir 0.9661980626743254
# --------------
# Current X: 17.978317743240936, Current Y: 84.96829439425103
# Goal X: 18, Goal Y: 84
# Angle absolu 88.71723492596395
# Angle relatif -0.4544502647196964
# Distance à parcourir 0.9685371207115084
# --------------
# Current X: 17.986497272430913, Current Y: 83.97244599036769
# Goal X: 18, Goal Y: 83
# Angle absolu 89.20448066565869
# Angle relatif 0.48435940159093605
# Distance à parcourir 0.9725397307226065
# --------------
# Current X: 18.01754249751634, Current Y: 82.90499990742966
# Goal X: 18, Goal Y: 82
# Angle absolu 91.11048101065568
# Angle relatif 1.9013911333095734
# Distance à parcourir 0.9051699131471368
# --------------
# Current X: 18.006782511642882, Current Y: 81.92706955951996
# Goal X: 18, Goal Y: 81
# Angle absolu 90.41917281657427
# Angle relatif -0.67271065427407
# Distance à parcourir 0.9270943698743542
# --------------
# Current X: 18.024844045991415, Current Y: 80.98176483794198
# Goal X: 18, Goal Y: 80
# Angle absolu 91.44958873765991
# Angle relatif 1.0359936327952823
# Distance à parcourir 0.9820791330847364
# --------------
# Current X: 18.000619907587293, Current Y: 79.95988101378789
# Goal X: 18, Goal Y: 79
# Angle absolu 90.0370025898959
# Angle relatif -1.4097632190274965
# Distance à parcourir 0.9598812139613369
# --------------
# Current X: 18.00535465923659, Current Y: 78.93954240603894
# Goal X: 18, Goal Y: 78
# Angle absolu 90.32653773938442
# Angle relatif 0.2910176142114409
# Distance à parcourir 0.939557664606584
# --------------
# Current X: 17.962468892111733, Current Y: 77.94194440841451
# Goal X: 18, Goal Y: 77
# Angle absolu 87.71829718268398
# Angle relatif -2.606034970198124
# Distance à parcourir 0.9426918121012241
# --------------
# Current X: 18.004447795371643, Current Y: 76.99381228462506
# Goal X: 18, Goal Y: 76
# Angle absolu 90.25642488568026
# Angle relatif 2.5188140442151337
# Distance à parcourir 0.9938222376035662
# --------------
# Current X: 17.99165332432649, Current Y: 75.95013833240333
# Goal X: 18, Goal Y: 75
# Angle absolu 89.49668698596075
# Angle relatif -0.7474670348199055
# Distance à parcourir 0.9501749931970289
# --------------
# Current X: 17.96456582637446, Current Y: 74.9042394430365
# Goal X: 18, Goal Y: 74
# Angle absolu 87.75591480121804
# Angle relatif -1.7363952217652638
# Distance à parcourir 0.9049334511462644
# --------------
# Current X: 18.02975420490337, Current Y: 74.00847976862217
# Goal X: 18, Goal Y: 73
# Angle absolu 91.68996544003645
# Angle relatif 3.951235586754109
# Distance à parcourir 1.0089186074355303
# --------------
# Current X: 17.973471018133914, Current Y: 72.90830603275775
# Goal X: 18, Goal Y: 72
# Angle absolu 88.3270322467424
# Angle relatif -3.3603190062772796
# Distance à parcourir 0.9086933674364382
# --------------
# Current X: 18.03335656306888, Current Y: 71.99336062334042
# Goal X: 18, Goal Y: 71
# Angle absolu 91.92324155137132
# Angle relatif 3.5910112951433746
# Distance à parcourir 0.9939205140769759
# --------------
# Current X: 17.97923824521131, Current Y: 70.93786933026983
# Goal X: 18, Goal Y: 70
# Angle absolu 88.73184181712466
# Angle relatif -3.188666456451159
# Distance à parcourir 0.9380991051710327
# --------------
# Current X: 17.98938911091852, Current Y: 69.96175691761519
# Goal X: 18, Goal Y: 69
# Angle absolu 89.36789173608811
# Angle relatif 0.6220569124794224
# Distance à parcourir 0.9618154498383624
# --------------
# Current X: 17.96427327682954, Current Y: 68.98808654372766
# Goal X: 18, Goal Y: 68
# Angle absolu 87.92923088371838
# Angle relatif -1.4331628710044413
# Distance à parcourir 0.9887322269675313
# --------------
# Current X: 17.963804363609327, Current Y: 67.9099791291421
# Goal X: 18, Goal Y: 67
# Angle absolu 87.7221845533134
# Angle relatif -0.21234754317957538
# Distance à parcourir 0.9106987095455571
# --------------
# Current X: 18.0122615470292, Current Y: 66.976116556587
# Goal X: 18, Goal Y: 66
# Angle absolu 90.7196865396687
# Angle relatif 2.9960382570808264
# Distance à parcourir 0.9761935656307177
# --------------
# Current X: 18.020926976181524, Current Y: 65.9766409050866
# Goal X: 18, Goal Y: 65
# Angle absolu 91.22751765890261
# Angle relatif 0.49728534778465416
# Distance à parcourir 0.976865085782305
# --------------
# Current X: 17.993787574581322, Current Y: 64.9904302440077
# Goal X: 18, Goal Y: 64
# Angle absolu 89.64061972942977
# Angle relatif -1.5898402879244173
# Distance à parcourir 0.9904497273838435
# --------------
# Current X: 18.005550366604545, Current Y: 63.94002931458199
# Goal X: 18, Goal Y: 63
# Angle absolu 90.33829677516084
# Angle relatif 0.693034814045447
# Distance à parcourir 0.9400457004012803
# --------------
# Current X: 18.039418786321146, Current Y: 62.925560929073555
# Goal X: 18, Goal Y: 62
# Angle absolu 92.43870065543769
# Angle relatif 2.103178117873327
# Distance à parcourir 0.926399953660693
# --------------
# Current X: 18.037175585163286, Current Y: 61.9282502409368
# Goal X: 18, Goal Y: 61
# Angle absolu 92.29341866973816
# Angle relatif -0.14441749494517353
# Distance à parcourir 0.9289943670073872
# --------------
# Current X: 17.97615084860901, Current Y: 60.95473799364796
# Goal X: 18, Goal Y: 60
# Angle absolu 88.56906123249853
# Angle relatif -3.7254468774592198
# Distance à parcourir 0.9550358205517753
# --------------
# Current X: 18.036406418743027, Current Y: 59.96150840061797
# Goal X: 18, Goal Y: 59
# Angle absolu 92.1684034669821
# Angle relatif 3.593685816842438
# Distance à parcourir 0.9621973975149927
# --------------
# Current X: 17.967453709852368, Current Y: 58.921526815228646
# Goal X: 18, Goal Y: 58
# Angle absolu 87.97728044663994
# Angle relatif -4.2193482357359215
# Distance à parcourir 0.9221013676314682
# --------------
# Current X: 18.004930011902278, Current Y: 57.98739363193529
# Goal X: 18, Goal Y: 57
# Angle absolu 90.28607286756822
# Angle relatif 2.3278186019346094
# Distance à parcourir 0.9874059395222012
# --------------
# Current X: 18.030111885928395, Current Y: 56.93962984242603
# Goal X: 18, Goal Y: 56
# Angle absolu 91.8355033562266
# Angle relatif 1.541550159393509
# Distance à parcourir 0.940112209500403
# --------------
# Current X: 18.00030418363608, Current Y: 55.957268205276584
# Goal X: 18, Goal Y: 55
# Angle absolu 90.01820643144897
# Angle relatif -1.8320881887079565
# Distance à parcourir 0.9572682536056113
# --------------
# Current X: 18.007893158761338, Current Y: 55.00460428294899
# Goal X: 18, Goal Y: 54
# Angle absolu 90.45016270192629
# Angle relatif 0.44840092292973566
# Distance à parcourir 1.0046352906775096
# --------------
# Current X: 18.01606509288893, Current Y: 53.93274825252809
# Goal X: 18, Goal Y: 53
# Angle absolu 90.98673036029487
# Angle relatif 0.5349068200887785
# Distance à parcourir 0.9328865900010251
# --------------
# Current X: 17.970415358472934, Current Y: 52.90556726365745
# Goal X: 18, Goal Y: 52
# Angle absolu 88.12882764860734
# Angle relatif -2.861410136040149
# Distance à parcourir 0.906050395961688
# --------------
# Current X: 17.995407855830383, Current Y: 51.94816106205324
# Goal X: 18, Goal Y: 51
# Angle absolu 89.72250661500496
# Angle relatif 1.5672570384864457
# Distance à parcourir 0.9481721823498086
# --------------
# Current X: 17.9935125701769, Current Y: 50.92154935619718
# Goal X: 18, Goal Y: 50
# Angle absolu 89.59666163701547
# Angle relatif -0.11266293516810322
# Distance à parcourir 0.9215721906899922
# --------------
# Current X: 17.96472612428457, Current Y: 49.924872500371336
# Goal X: 18, Goal Y: 49
# Angle absolu 87.81584475233115
# Angle relatif -1.780627370910409
# Distance à parcourir 0.9255449142268108
# --------------
# Current X: 18.001068875515752, Current Y: 48.97937099440944
# Goal X: 18, Goal Y: 48
# Angle absolu 90.06253200463492
# Angle relatif 2.2525225405079965
# Distance à parcourir 0.9793715776891881
# --------------
# Current X: 17.977716117683425, Current Y: 47.960108276592585
# Goal X: 18, Goal Y: 47
# Angle absolu 88.67041744109562
# Angle relatif -1.3935658389814876
# Distance à parcourir 0.9603668435512979
# --------------
# Current X: 17.966030965767565, Current Y: 46.93652136045911
# Goal X: 18, Goal Y: 46
# Angle absolu 87.92270680929019
# Angle relatif -0.752327738740405
# Distance à parcourir 0.9371372118760771
# --------------
# Current X: 17.989334612613963, Current Y: 45.98647538260036
# Goal X: 18, Goal Y: 45
# Angle absolu 89.38056449600911
# Angle relatif 1.4528523419827906
# Distance à parcourir 0.9865330359215663
# --------------
# Current X: 18.037237358552474, Current Y: 44.88899870813229
# Goal X: 18, Goal Y: 44
# Angle absolu 92.39853782044442
# Angle relatif 3.0255407429140604
# Distance à parcourir 0.889778244245637
# --------------
# Current X: 18.011397403031808, Current Y: 43.92327902584091
# Goal X: 18, Goal Y: 43
# Angle absolu 90.70725090173369
# Angle relatif -1.6631468772795301
# Distance à parcourir 0.9233493706899972
# --------------
# Current X: 18.00570185507435, Current Y: 42.946472050841884
# Goal X: 18, Goal Y: 42
# Angle absolu 90.34516421144481
# Angle relatif -0.37407216689381073
# Distance à parcourir 0.9464892255995997
# --------------
# Current X: 17.966745033129797, Current Y: 41.97152188398711
# Goal X: 18, Goal Y: 41
# Angle absolu 88.03954430201163
# Angle relatif -2.306473913904725
# Distance à parcourir 0.9720908722374668
# --------------
# Current X: 18.027042660203367, Current Y: 40.93445840298567
# Goal X: 18, Goal Y: 40
# Angle absolu 91.65764250752741
# Angle relatif 3.611680384901149
# Distance à parcourir 0.9348496201964259
# --------------
# Current X: 17.986911817507327, Current Y: 39.93347685705109
# Goal X: 18, Goal Y: 39
# Angle absolu 89.19671443509074
# Angle relatif -2.453737542220381
# Distance à parcourir 0.9335686065688709
# --------------
# Current X: 17.972710637400365, Current Y: 38.957517969075205
# Goal X: 18, Goal Y: 38
# Angle absolu 88.36750617657475
# Angle relatif -0.8376706266895582
# Distance à parcourir 0.9579067649896831
# --------------
# Current X: 17.99365277053383, Current Y: 37.925091506963916
# Goal X: 18, Goal Y: 37
# Angle absolu 89.60688888532421
# Angle relatif 1.2423028782561119
# Distance à parcourir 0.9251132814843087
# --------------
# Current X: 18.00012163404323, Current Y: 36.930498505783895
# Goal X: 18, Goal Y: 36
# Angle absolu 90.00748965983192
# Angle relatif 0.3951017576714406
# Distance à parcourir 0.9304985137338487
# --------------
# Current X: 18.007990371856778, Current Y: 35.97747046825879
# Goal X: 18, Goal Y: 35
# Angle absolu 90.46835623364275
# Angle relatif 0.4645854758742587
# Distance à parcourir 0.9775031265220901
# --------------
# True

# %% [markdown]
# ### Algorithme RRT*
#
# Nous le gardons juste à des fins de démonstration. L'Algorithme fonctionne pas très bien sur une carte aussi grande que celle d'HEC. Il est préférable d'utiliser une carte simple telle que celle de base.
#
# Il est nécessaire de télécharger la librairie [PythonRobotics](https://github.com/AtsushiSakai/PythonRobotics).
# Dans le dossier du projet, extraire le .zip ou exécuter
# ```git
# git clone https://github.com/AtsushiSakai/PythonRobotics.git
# ```

# %%
# Crée les obstacles circulaires pour l'algorithme RRT*

obstacle = generateObstacleRRTStar(room, 1.2) #Rayon de 1.2 pour créer une zone de sécurité
showmap(room = room, dog = dog, obstacle = obstacle)

# %%
# Point de destination
destination = [12,5]

# Crée le chemin grâce à l'algorithme RRT*
rrt_star = RRTStar(
        start=[dog.x, dog.y], #utilise directement la position actuelle du chien
        goal=destination,
        rand_area=[2, 15],
        obstacle_list = obstacle,
        goal_sample_rate=1,
        expand_dis=5,
        max_iter=200,
        search_until_max_iter=False)
pathRRTStar = rrt_star.planning(animation=False)
    
showmap(room, dog = dog, goal = destination, obstacle = obstacle, path=pathRRTStar)
# Out:
# Iter: 0 , number of nodes: 1
# Iter: 1 , number of nodes: 2
# Iter: 2 , number of nodes: 3
# Iter: 3 , number of nodes: 4
# Iter: 4 , number of nodes: 5
# Iter: 5 , number of nodes: 6
# Iter: 6 , number of nodes: 6
# Iter: 7 , number of nodes: 6
# Iter: 8 , number of nodes: 6
# Iter: 9 , number of nodes: 6
# Iter: 10 , number of nodes: 7
# Iter: 11 , number of nodes: 7
# Iter: 12 , number of nodes: 8
# Iter: 13 , number of nodes: 9
# Iter: 14 , number of nodes: 9
# Iter: 15 , number of nodes: 10
# Iter: 16 , number of nodes: 10
# Iter: 17 , number of nodes: 10
# Iter: 18 , number of nodes: 10
# Iter: 19 , number of nodes: 11
# Iter: 20 , number of nodes: 12
# Iter: 21 , number of nodes: 13
# Iter: 22 , number of nodes: 13
# Iter: 23 , number of nodes: 14
# Iter: 24 , number of nodes: 15
